# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv('charity_data.csv')
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
drop_df = application_df.drop(columns= ["EIN", "NAME"])
drop_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
drop_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
counts_hold = drop_df["APPLICATION_TYPE"].value_counts()
counts_hold
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(counts_hold[counts_hold<500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classif = drop_df["CLASSIFICATION"].value_counts()
classif
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
drop_df['CLASSIFICATION'].value_counts().loc[lambda x : x >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classif[classif<1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
cat_data = pd.get_dummies(drop_df)

# %%
# Split our preprocessed data into our features and target arrays
X= cat_data.drop('IS_SUCCESSFUL', axis=1).values
y= cat_data['IS_SUCCESSFUL'].values
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 31)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = X_train_scaled.shape[1]
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 200
hidden_nodes_layer3 = 30

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 80)                9360
#
#  dense_5 (Dense)             (None, 200)               16200
#
#  dense_6 (Dense)             (None, 30)                6030
#
#  dense_7 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 31,621
# Trainable params: 31,621
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 7s 5ms/step - loss: 0.5776 - accuracy: 0.7144
# Epoch 2/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5571 - accuracy: 0.7292
# Epoch 3/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5533 - accuracy: 0.7301
# Epoch 4/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5518 - accuracy: 0.7303
# Epoch 5/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5502 - accuracy: 0.7302
# Epoch 6/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5487 - accuracy: 0.7318
# Epoch 7/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5479 - accuracy: 0.7317
# Epoch 8/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5465 - accuracy: 0.7318
# Epoch 9/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5461 - accuracy: 0.7317
# Epoch 10/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5456 - accuracy: 0.7335
# Epoch 11/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5448 - accuracy: 0.7327
# Epoch 12/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5443 - accuracy: 0.7324
# Epoch 13/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5436 - accuracy: 0.7342
# Epoch 14/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5427 - accuracy: 0.7346
# Epoch 15/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5420 - accuracy: 0.7354
# Epoch 16/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5418 - accuracy: 0.7352
# Epoch 17/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5408 - accuracy: 0.7353
# Epoch 18/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5405 - accuracy: 0.7363
# Epoch 19/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5405 - accuracy: 0.7356
# Epoch 20/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5401 - accuracy: 0.7359
# Epoch 21/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5393 - accuracy: 0.7374
# Epoch 22/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5390 - accuracy: 0.7371
# Epoch 23/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5388 - accuracy: 0.7368
# Epoch 24/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5382 - accuracy: 0.7371
# Epoch 25/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5380 - accuracy: 0.7376
# Epoch 26/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5375 - accuracy: 0.7385
# Epoch 27/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5367 - accuracy: 0.7367
# Epoch 28/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5367 - accuracy: 0.7385
# Epoch 29/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5361 - accuracy: 0.7388
# Epoch 30/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5363 - accuracy: 0.7389
# Epoch 31/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5359 - accuracy: 0.7385
# Epoch 32/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5353 - accuracy: 0.7380
# Epoch 33/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5351 - accuracy: 0.7388
# Epoch 34/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5238 - accuracy: 0.7446
# Epoch 150/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5237 - accuracy: 0.7441
# Epoch 151/200
# 804/804 [==============================] - 27s 34ms/step - loss: 0.5239 - accuracy: 0.7444
# Epoch 152/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5234 - accuracy: 0.7446
# Epoch 153/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5240 - accuracy: 0.7442
# Epoch 154/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5239 - accuracy: 0.7442
# Epoch 155/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5234 - accuracy: 0.7447
# Epoch 156/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5235 - accuracy: 0.7448
# Epoch 157/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5235 - accuracy: 0.7445
# Epoch 158/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7448
# Epoch 159/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5238 - accuracy: 0.7447
# Epoch 160/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7448
# Epoch 161/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5234 - accuracy: 0.7446
# Epoch 162/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5234 - accuracy: 0.7448
# Epoch 163/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7444
# Epoch 164/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5237 - accuracy: 0.7446
# Epoch 165/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7440
# Epoch 166/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5234 - accuracy: 0.7448
# Epoch 167/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5238 - accuracy: 0.7446
# Epoch 168/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7443
# Epoch 169/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7443
# Epoch 170/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7446
# Epoch 171/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7448
# Epoch 172/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5240 - accuracy: 0.7450
# Epoch 173/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5234 - accuracy: 0.7446
# Epoch 174/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5234 - accuracy: 0.7445
# Epoch 175/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5235 - accuracy: 0.7446
# Epoch 176/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5232 - accuracy: 0.7448
# Epoch 177/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5241 - accuracy: 0.7442
# Epoch 178/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7446
# Epoch 179/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7447
# Epoch 180/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7448
# Epoch 181/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5234 - accuracy: 0.7444
# Epoch 182/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5239 - accuracy: 0.7446
# Epoch 183/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7448
# Epoch 184/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5239 - accuracy: 0.7443
# Epoch 185/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7442
# Epoch 186/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5232 - accuracy: 0.7448
# Epoch 187/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5235 - accuracy: 0.7446
# Epoch 188/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5232 - accuracy: 0.7446
# Epoch 189/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7449
# Epoch 190/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5235 - accuracy: 0.7446
# Epoch 191/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5236 - accuracy: 0.7446
# Epoch 192/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7448
# Epoch 193/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5232 - accuracy: 0.7448
# Epoch 194/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7443
# Epoch 195/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5233 - accuracy: 0.7445
# Epoch 196/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5232 - accuracy: 0.7451
# Epoch 197/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5229 - accuracy: 0.7449
# Epoch 198/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5234 - accuracy: 0.7446
# Epoch 199/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5235 - accuracy: 0.7443
# Epoch 200/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5230 - accuracy: 0.7446

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5783 - accuracy: 0.7341 - 1s/epoch - 5ms/step
# Loss: 0.578346848487854, Accuracy: 0.7341107726097107

# %%
# Export our model to HDF5 file
nn_model.save('../deep-learning-challenge/AlphabetSoupCharity_Optimization_v1.h5')
